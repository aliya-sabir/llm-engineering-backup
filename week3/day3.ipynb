# %% [markdown]
# # Tokenizers
#
# Please can I bring you back to the wonderful Google Colab where we'll look at different Tokenizers:
#
# https://colab.research.google.com/drive/1WD6Y2N7ctQi1X9wa6rpkg8UfyA4iSVuz?usp=sharing

# %% [markdown]
# Token -> fragment of word
# Token id -> number associated to the token
# 0.75 of a word to token
# tokenizer has dictionary
# this dictionary has special tokens to signal the start of a sentence
# we haven't configured a special token for this purpose rather the model learned to associate through training
#
# tokens-> token ids the numbers a model can understand
# by embedding these token ids we might get vectors or another token id
#
# Llama is a base model -> doesn't expect user or system prompts
# chat/instruct variants -> trained with assistant and user prompts
#
# The chat format is basically:
#
# A control interface built entirely out of tokens.
#
# There is no internal “chat mode.”
#
# There is only:
#
# token sequence → next token probabilities
#
# The format works because the model learned statistical regularities about conversations written that way.
#
# Step	                              With API	             Using apply_chat_template manually
# Python dicts → text with markers	Done internally by SDK	You do it explicitly with apply_chat_template
